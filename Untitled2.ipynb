# %% [markdown]
# <a href="https://colab.research.google.com/github/fluffypupp/SpecialistPython2_v2/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys, cv2
import matplotlib.pyplot as plt

import numpy as np
from scipy.signal import medfilt, convolve2d

from numpy.typing import ArrayLike


image = cv2.imread('/content/blowup17.jpg', cv2.IMREAD_GRAYSCALE)

fig, ax = plt.subplots(1, 4, figsize=(25, 50))
plt.subplots_adjust(wspace=0, hspace=0)

ax[0].imshow(image, cmap='gray')
a = medfilt(image)
ax[1].imshow(a, cmap='gray')
a = medfilt(a)
ax[2].imshow(a, cmap='gray')
a = medfilt(a)
ax[3].imshow(a, cmap='gray')
# ax[2].imshow(medfilt(cv2.medianBlur(a, 35)), cmap='gray')
# a = medfilt(a)
# ax[3].imshow(medfilt(cv2.medianBlur(a, 135)), cmap='gray')
